# %%
import pandas as pd
import pandas_profiling

# %%
df = pd.read_excel('data/data Procena darovitosti.xlsx', sheet_name='Sheet1')

# %%
df.head()
# Out:
#    RB  naspol  nasss  nastrs  nasvl  naslm  nasvp  nastk  nasmr  nasinter  \
# 0   1       1      3       2     44     33     55     48     57        55
# 1   2       1      3       2     50     40     44     42     38        60
# 2   3       1      3       2     42     42     36     43     40        56
# 3   4       1      3       1     50     60     32     28     34        46
# 4   5       1      3       1     46     45     43     61     53        51
#
#    ...  ucetk  ucemr  uceinter  uceintra  ucepriro  ucefil  rpm  vs  shv  \
# 0  ...     42     55        49        54        40      39   30  13   17
# 1  ...     37     36        65        63        44      33   36  12   16
# 2  ...     36     34        45        37        29      25   36  13   16
# 3  ...     55     60        45        45        51      37   31  12   10
# 4  ...     54     41        52        57        51      46   33   5   13
#
#    Rnasvl
# 0    10.0
# 1    30.0
# 2     6.0
# 3    30.0
# 4    15.0
#
# [5 rows x 50 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 50 columns):
# RB          151 non-null int64
# naspol      151 non-null int64
# nasss       151 non-null int64
# nastrs      151 non-null int64
# nasvl       151 non-null int64
# naslm       151 non-null int64
# nasvp       151 non-null int64
# nastk       151 non-null int64
# nasmr       151 non-null int64
# nasinter    151 non-null int64
# nasintra    151 non-null int64
# naspriro    151 non-null int64
# nastfil     151 non-null int64
# rodss       151 non-null int64
# rodpol      151 non-null int64
# rodvl       151 non-null int64
# rodlm       151 non-null int64
# rodvp       151 non-null int64
# rodtk       151 non-null int64
# rodmr       151 non-null int64
# rodintr     151 non-null int64
# rodintra    151 non-null int64
# rodprir     151 non-null int64
# rodfil      151 non-null int64
# vrspol      151 non-null int64
# vrsray      151 non-null int64
# vrsvl       151 non-null int64
# vrslm       151 non-null int64
# vrsvp       151 non-null int64
# vrstk       151 non-null int64
# vrsmr       151 non-null int64
# vrsintr     151 non-null int64
# vrsintra    151 non-null int64
# vrsprir     151 non-null int64
# vrsfil      151 non-null int64
# ucepol      151 non-null int64
# ucenraz     151 non-null int64
# ucevl       151 non-null int64
# ucelm       151 non-null int64
# ucevp       151 non-null int64
# ucetk       151 non-null int64
# ucemr       151 non-null int64
# uceinter    151 non-null int64
# uceintra    151 non-null int64
# ucepriro    151 non-null int64
# ucefil      151 non-null int64
# rpm         151 non-null int64
# vs          151 non-null int64
# shv         151 non-null int64
# Rnasvl      151 non-null float64
# dtypes: float64(1), int64(49)
# memory usage: 59.1 KB

# %%
df.describe()
# Out:
#                RB      naspol       nasss      nastrs       nasvl       naslm  \
# count  151.000000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean    76.000000    1.158940    2.841060    1.675497   57.033113   57.033113
# std     43.734045    0.366837    0.448594    0.820972    7.740299    9.427914
# min      1.000000    1.000000    1.000000    1.000000   31.000000   33.000000
# 25%     38.500000    1.000000    3.000000    1.000000   52.000000   52.000000
# 50%     76.000000    1.000000    3.000000    1.000000   58.000000   58.000000
# 75%    113.500000    1.000000    3.000000    2.000000   63.000000   64.000000
# max    151.000000    2.000000    3.000000    3.000000   70.000000   73.000000
#
#             nasvp       nastk       nasmr    nasinter  ...       ucetk  \
# count  151.000000  151.000000  151.000000  151.000000  ...  151.000000
# mean    58.754967   56.066225   54.980132   63.801325  ...   57.344371
# std      9.519080   10.430512   10.436136    9.328823  ...    9.488974
# min     24.000000    5.000000   21.000000   30.000000  ...   21.000000
# 25%     55.000000   49.500000   49.500000   60.000000  ...   51.000000
# 50%     62.000000   58.000000   56.000000   66.000000  ...   58.000000
# 75%     66.000000   64.000000   62.000000   71.000000  ...   63.500000
# max     72.000000   73.000000   75.000000   75.000000  ...   74.000000
#
#             ucemr    uceinter    uceintra    ucepriro      ucefil         rpm  \
# count  151.000000  151.000000  151.000000  151.000000  151.000000  151.000000
# mean    55.046358   63.344371   63.668874   52.523179   53.019868   32.231788
# std     10.563041    8.217904    7.888998   11.488449   12.171809    4.302625
# min     30.000000   42.000000   37.000000   21.000000   23.000000   11.000000
# 25%     48.000000   59.000000   59.000000   45.000000   45.000000   31.000000
# 50%     56.000000   65.000000   64.000000   53.000000   53.000000   33.000000
# 75%     63.000000   70.000000   70.000000   60.000000   63.000000   35.000000
# max     75.000000   75.000000   75.000000   75.000000   75.000000   36.000000
#
#                vs         shv      Rnasvl
# count  151.000000  151.000000  151.000000
# mean     9.940397   14.039735   76.000000
# std      3.774002    2.430036   43.692181
# min      0.000000    8.000000    1.000000
# 25%      8.000000   12.000000   37.500000
# 50%     10.000000   14.000000   74.500000
# 75%     13.000000   16.000000  113.000000
# max     18.000000   20.000000  150.000000
#
# [8 rows x 50 columns]

# %%
darovitost_profile = pandas_profiling.ProfileReport(df)
darovitost_profile.to_file(outputfile='reports/darovitost_profile.html')
darovitost_profile
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
#             margin-left: 1em;
#         }
#
#         .center-img {
#             margin-left: auto !important;
#             margin-right: auto !important;
#             display: block;
#         }
#
#         /* Table example_values */
#             table.example_values {
#                 border: 0;
#             }
#
#             .example_values th {
#                 border: 0;
#                 padding: 0 ;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .example_values tr, .example_values td{
#                 border: 0;
#                 padding: 0;
#                 color: #555;
#             }
#
#         /* STATS */
#             table.stats {
#                 border: 0;
#             }
#
#             .stats th {
#                 border: 0;
#                 padding: 0 2em 0 0;
#                 color: #555;
#                 font-weight: 600;
#             }
#
#             .stats tr {
#                 border: 0;
#             }
#
#             .stats td{
#                 color: #555;
#                 padding: 1px;
#                 border: 0;
#             }
#
#
#         /* Sample table */
#             table.sample {
#                 border: 0;
#                 margin-bottom: 2em;
#                 margin-left:1em;
#             }
#             .sample tr {
#                 border:0;
#             }
#             .sample td, .sample th{
#                 padding: 0.5em;
#                 white-space: nowrap;
#                 border: none;
#
#             }
#
#             .sample thead {
#                 border-top: 0;
#                 border-bottom: 2px solid #ddd;
#             }
#
#             .sample td {
#                 width:100%;
#             }
#
#
#         /* There is no good solution available to make the divs equal height and then center ... */
#             .histogram {
#                 margin-top: 3em;
#             }
#         /* Freq table */
#
#             table.freq {
#                 margin-bottom: 2em;
#                 border: 0;
#             }
#             table.freq th, table.freq tr, table.freq td {
#                 border: 0;
#                 padding: 0;
#             }
#
#             .freq thead {
#                 font-weight: 600;
#                 white-space: nowrap;
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#
#             }
#
#             td.fillremaining{
#                 width:auto;
#                 max-width: none;
#             }
#
#             td.number, th.number {
#                 text-align:right ;
#             }
#
#         /* Freq mini */
#             .freq.mini td{
#                 width: 50%;
#                 padding: 1px;
#                 font-size: 12px;
#
#             }
#             table.freq.mini {
#                  width:100%;
#             }
#             .freq.mini th {
#                 overflow: hidden;
#                 text-overflow: ellipsis;
#                 white-space: nowrap;
#                 max-width: 5em;
#                 font-weight: 400;
#                 text-align:right;
#                 padding-right: 0.5em;
#             }
#
#             .missing {
#                 color: #a94442;
#             }
#             .alert, .alert > th, .alert > td {
#                 color: #a94442;
#             }
#
#
#         /* Bars in tables */
#             .freq .bar{
#                 float: left;
#                 width: 0;
#                 height: 100%;
#                 line-height: 20px;
#                 color: #fff;
#                 text-align: center;
#                 background-color: #337ab7;
#                 border-radius: 3px;
#                 margin-right: 4px;
#             }
#             .other .bar {
#                 background-color: #999;
#             }
#             .missing .bar{
#                 background-color: #a94442;
#             }
#             .tooltip-inner {
#                 width: 100%;
#                 white-space: nowrap;
#                 text-align:left;
#             }
#
#             .extrapadding{
#                 padding: 2em;
#             }
#
#             .pp-anchor{
#
#             }
#
# </style>
#
# <div class="container pandas-profiling">
#     <div class="row headerrow highlight">
#         <h1>Overview</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-6 namecol">
#         <p class="h4">Dataset info</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Number of variables</th>
#                 <td>50 </td>
#             </tr>
#             <tr>
#                 <th>Number of observations</th>
#                 <td>151 </td>
#             </tr>
#             <tr>
#                 <th>Total Missing (%)</th>
#                 <td>0.0% </td>
#             </tr>
#             <tr>
#                 <th>Total size in memory</th>
#                 <td>59.1 KiB </td>
#             </tr>
#             <tr>
#                 <th>Average record size in memory</th>
#                 <td>400.5 B </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-6 namecol">
#         <p class="h4">Variables types</p>
#         <table class="stats" style="margin-left: 1em;">
#             <tbody>
#             <tr>
#                 <th>Numeric</th>
#                 <td>43 </td>
#             </tr>
#             <tr>
#                 <th>Categorical</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Boolean</th>
#                 <td>5 </td>
#             </tr>
#             <tr>
#                 <th>Date</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Text (Unique)</th>
#                 <td>0 </td>
#             </tr>
#             <tr>
#                 <th>Rejected</th>
#                 <td>2 </td>
#             </tr>
#             <tr>
#                 <th>Unsupported</th>
#                 <td>0 </td>
#             </tr>
#             </tbody>
#         </table>
#     </div>
#     <div class="col-md-12" style="padding-left: 1em;">
#
#         <p class="h4">Warnings</p>
#         <ul class="list-unstyled"><li><a href="#pp_var_Rnasvl"><code>Rnasvl</code></a> is highly correlated with <a href="#pp_var_nasvl"><code>nasvl</code></a> (ρ = 0.97042) <span class="label label-primary">Rejected</span></li><li><a href="#pp_var_ucenraz"><code>ucenraz</code></a> is highly correlated with <a href="#pp_var_vrsray"><code>vrsray</code></a> (ρ = 0.95384) <span class="label label-primary">Rejected</span></li> </ul>
#     </div>
# </div>
#     <div class="row headerrow highlight">
#         <h1>Variables</h1>
#     </div>
#     <div class="row variablerow">
#     <div class="col-md-3 namecol">
#         <p class="h4 pp-anchor" id="pp_var_RB">RB<br/>
#             <small>Numeric</small>
#         </p>
#     </div><div class="col-md-6">
#     <div class="row">
#         <div class="col-sm-6">
#             <table class="stats ">
#                 <tr>
#                     <th>Distinct count</th>
#                     <td>151</td>
#                 </tr>
#                 <tr>
#                     <th>Unique (%)</th>
#                     <td>100.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (%)</th>
#                     <td>0.0%</td>
#                 </tr>
#                 <tr class="ignore">
#                     <th>Missing (n
